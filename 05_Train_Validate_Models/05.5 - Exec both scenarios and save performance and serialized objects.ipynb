# %%
# %load_ext autoreload
# %autoreload 2


def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn

import sys
import os
import time


#needed to import utils.py
sys.path.append('../') 

import utils
import utils_preprocessing
import utils_exec_models
import utils_exec_models_new

import numpy as np
import pandas as pd
#to view entire text of the comuns
pd.set_option('display.max_colwidth', None) 

import sklearn as sk

import matplotlib.pyplot as plt
import seaborn as sns

from IPython.core.display import HTML

from IPython.display import clear_output

# Import module for data visualization
from plotnine import *
import plotnine

import pickle

# %matplotlib inline

# %%
# get train and tezt sets INCLUDING the Diagnosis_Delay feature
X_train_all, y_train_all, X_valid_all, y_valid_all = utils.get_train_and_validation_data(
    scaled=True,
    use_diagnosis_delay=True,
)

# get train and tezt sets REMOVING the Diagnosis_Delay feature
X_train_ndd, y_train_ndd, X_valid_ndd, y_valid_ndd = utils.get_train_and_validation_data(
    scaled=True,
    use_diagnosis_delay=False,
)



datasets = [
    ['All_Features', X_train_all, y_train_all, X_valid_all, y_valid_all],
    ['without_Diagnosis_Delay', X_train_ndd, y_train_ndd, X_valid_ndd, y_valid_ndd],
] 



# pattern to save the instance for each gridSearch object generated
dir_dest = os.path.abspath('exec_results')


# define the Cross-Validation strategy
CV_N_SPLITS = 4
CV_N_REPEATS = 3
RANDOM_STATE = 42

cv = sk.model_selection.RepeatedStratifiedKFold(n_splits=CV_N_SPLITS, n_repeats=CV_N_REPEATS, random_state=RANDOM_STATE)


grids_executed = []


# get all param_grid combinations for each classifier
testing = True
testing = False

grid_configs = [
#     utils_exec_models_new.create_models_DT_grid(testing=testing),
#     utils_exec_models_new.create_models_NB_Gaussian_grid(testing=testing),
#     utils_exec_models_new.create_models_NB_Complement_grid(testing=testing),
#     utils_exec_models_new.create_models_kNN_grid(testing=testing),
#     utils_exec_models_new.create_models_RadiusNN_grid(testing=testing),
#     utils_exec_models_new.create_models_SVM_grid(testing=testing),    
#     utils_exec_models_new.create_models_RF_grid(testing=testing),
#     utils_exec_models_new.create_models_NN_grid(qty_features=X_train.shape[1], testing=testing),
]



# ======================================================================
# ======================================================================
# ======================================================================
# ======================================================================

# for each features_config and datasets
for features_config, X_train, y_train, X_valid, y_valid in datasets:
    # for each ML algorithm and param_grid
    for classifier, param_grid in grid_configs: 
        model_desc = utils.get_model_short_description(classifier).replace('-', '')
        utils.print_string_with_separators(f'{model_desc} - {features_config}')


        # ====================================================
        # execute gridSearch in the Single-Model scenario
        # ====================================================
        scenario = 'Single_Model'
        print(f'   Executing {scenario}')
        
        grid = sk.model_selection.GridSearchCV(
            estimator=classifier, 
            param_grid=param_grid, 
            scoring=utils_exec_models_new.get_default_scoring(), 
            cv=cv,
            verbose=1,
            n_jobs=utils_exec_models_new.N_JOBS, #7
            return_train_score=True,
            refit=utils_exec_models_new.DEFAULT_SCORE # balanced accuracy
        )

        # fit the grid and save the trainning and validation performances
        grid, df_validation_performances = utils_exec_models_new.exec_grid_search_and_save_performances(
            dir_dest=dir_dest, 
            testing=testing, 
            grid=grid, 
            classifier=classifier, 
            scenario=scenario, 
            features_config=features_config, 
            X_train=X_train, 
            y_train=y_train, 
            X_valid=X_valid, 
            y_valid=y_valid,
        )

        print(f' FINISHED !!! [{model_desc} - {scenario} - {features_config}]')
        print()

        
        # ====================================================
        # execute gridSearch in the Ensemble_Imbalance scenario
        # ====================================================
        scenario = 'Ensemble_Imbalance'
        print(f'   Executing {scenario}')

        models_to_use_as_estimator = utils_exec_models_new.create_model_instances_from_performances(
            df=df_validation_performances
        )

        es_classifier, es_estimator, es_param_grid = utils_exec_models_new.create_models_BalancedBagging_grid(
            estimator=models_to_use_as_estimator,
            testing=testing,
        )

        es_grid = sk.model_selection.GridSearchCV(
            estimator=es_classifier, 
            param_grid=es_param_grid, 
            scoring=utils_exec_models_new.get_default_scoring(), 
            cv=cv,
            verbose=1,
            n_jobs=utils_exec_models_new.N_JOBS, #7
            return_train_score=True,
            refit=utils_exec_models_new.DEFAULT_SCORE # balanced accuracy
        )

        # fit the grid and save the trainning and validation performances
        es_grid, es_df_validation_performances = utils_exec_models_new.exec_grid_search_and_save_performances(
            dir_dest=dir_dest, 
            testing=testing, 
            grid=es_grid, 
            classifier=es_classifier, 
            scenario=scenario, 
            features_config=features_config, 
            X_train=X_train, 
            y_train=y_train, 
            X_valid=X_valid, 
            y_valid=y_valid,
        )
        
        
        clear_output() 

        print(f' FINISHED !!! [{model_desc} - {scenario} - {features_config}]')
        print()
        
#         break
#     break
    

    
print(f' FINISHED ALL !!!')
    
display(df_validation_performances.head(2))    
display(es_df_validation_performances)    

# ======================================================================
# ======================================================================
# ======================================================================
# ======================================================================
# Out:
#  FINISHED !!! [NN - Ensemble_Imbalance - without_Diagnosis_Delay]
#
#  FINISHED ALL !!!
#        Scenario                 Features            Model  balanced_accuracy  \
# 0  Single_Model  without_Diagnosis_Delay  Neural Networks               0.66
# 1  Single_Model  without_Diagnosis_Delay  Neural Networks               0.70
#
#    sensitivity  specificity  f1_score   AUC  accuracy  precision  ...  \
# 0         0.36         0.96      0.44  0.85      0.89       0.57  ...
# 1         0.45         0.95      0.48  0.87      0.89       0.52  ...
#
#   Estimator_Class Estimator_Hyperparams fit_time train_balanced_accuracy  \
# 0                                           0.01                    0.67
# 1                                           0.01                    0.67
#
#   train_sensitivity  train_specificity  train_f1_score  train_AUC  \
# 0              0.40               0.94            0.45       0.80
# 1              0.39               0.95            0.46       0.82
#
#    train_accuracy  train_precision
# 0            0.87             0.52
# 1            0.88             0.57
#
# [2 rows x 23 columns]
#               Scenario                 Features             Model  \
# 0   Ensemble_Imbalance  without_Diagnosis_Delay  Balanced Bagging
# 1   Ensemble_Imbalance  without_Diagnosis_Delay  Balanced Bagging
# 2   Ensemble_Imbalance  without_Diagnosis_Delay  Balanced Bagging
# 3   Ensemble_Imbalance  without_Diagnosis_Delay  Balanced Bagging
# 4   Ensemble_Imbalance  without_Diagnosis_Delay  Balanced Bagging
# 5   Ensemble_Imbalance  without_Diagnosis_Delay  Balanced Bagging
# 6   Ensemble_Imbalance  without_Diagnosis_Delay  Balanced Bagging
# 7   Ensemble_Imbalance  without_Diagnosis_Delay  Balanced Bagging
# 8   Ensemble_Imbalance  without_Diagnosis_Delay  Balanced Bagging
# 9   Ensemble_Imbalance  without_Diagnosis_Delay  Balanced Bagging
# 10  Ensemble_Imbalance  without_Diagnosis_Delay  Balanced Bagging
# 11  Ensemble_Imbalance  without_Diagnosis_Delay  Balanced Bagging
# 12  Ensemble_Imbalance  without_Diagnosis_Delay  Balanced Bagging
# 13  Ensemble_Imbalance  without_Diagnosis_Delay  Balanced Bagging
# 14  Ensemble_Imbalance  without_Diagnosis_Delay  Balanced Bagging
# 15  Ensemble_Imbalance  without_Diagnosis_Delay  Balanced Bagging
# 16  Ensemble_Imbalance  without_Diagnosis_Delay  Balanced Bagging
# 17  Ensemble_Imbalance  without_Diagnosis_Delay  Balanced Bagging
# 18  Ensemble_Imbalance  without_Diagnosis_Delay  Balanced Bagging
# 19  Ensemble_Imbalance  without_Diagnosis_Delay  Balanced Bagging
# 20  Ensemble_Imbalance  without_Diagnosis_Delay  Balanced Bagging
# 21  Ensemble_Imbalance  without_Diagnosis_Delay  Balanced Bagging
# 22  Ensemble_Imbalance  without_Diagnosis_Delay  Balanced Bagging
# 23  Ensemble_Imbalance  without_Diagnosis_Delay  Balanced Bagging
# 24  Ensemble_Imbalance  without_Diagnosis_Delay  Balanced Bagging
# 25  Ensemble_Imbalance  without_Diagnosis_Delay  Balanced Bagging
# 26  Ensemble_Imbalance  without_Diagnosis_Delay  Balanced Bagging
# 27  Ensemble_Imbalance  without_Diagnosis_Delay  Balanced Bagging
# 28  Ensemble_Imbalance  without_Diagnosis_Delay  Balanced Bagging
# 29  Ensemble_Imbalance  without_Diagnosis_Delay  Balanced Bagging
# 30  Ensemble_Imbalance  without_Diagnosis_Delay  Balanced Bagging
# 31  Ensemble_Imbalance  without_Diagnosis_Delay  Balanced Bagging
# 32  Ensemble_Imbalance  without_Diagnosis_Delay  Balanced Bagging
# 33  Ensemble_Imbalance  without_Diagnosis_Delay  Balanced Bagging
# 34  Ensemble_Imbalance  without_Diagnosis_Delay  Balanced Bagging
# 35  Ensemble_Imbalance  without_Diagnosis_Delay  Balanced Bagging
# 36  Ensemble_Imbalance  without_Diagnosis_Delay  Balanced Bagging
# 37  Ensemble_Imbalance  without_Diagnosis_Delay  Balanced Bagging
# 38  Ensemble_Imbalance  without_Diagnosis_Delay  Balanced Bagging
# 39  Ensemble_Imbalance  without_Diagnosis_Delay  Balanced Bagging
# 40  Ensemble_Imbalance  without_Diagnosis_Delay  Balanced Bagging
# 41  Ensemble_Imbalance  without_Diagnosis_Delay  Balanced Bagging
# 42  Ensemble_Imbalance  without_Diagnosis_Delay  Balanced Bagging
# 43  Ensemble_Imbalance  without_Diagnosis_Delay  Balanced Bagging
# 44  Ensemble_Imbalance  without_Diagnosis_Delay  Balanced Bagging
# 45  Ensemble_Imbalance  without_Diagnosis_Delay  Balanced Bagging
# 46  Ensemble_Imbalance  without_Diagnosis_Delay  Balanced Bagging
# 47  Ensemble_Imbalance  without_Diagnosis_Delay  Balanced Bagging
#
#     balanced_accuracy  sensitivity  specificity  f1_score   AUC  accuracy  \
# 0                0.83         0.91         0.74      0.48  0.89      0.76
# 1                0.83         0.91         0.74      0.48  0.89      0.76
# 2                0.82         0.89         0.75      0.47  0.89      0.76
# 3                0.82         0.89         0.75      0.47  0.89      0.76
# 4                0.82         0.89         0.74      0.47  0.88      0.76
# 5                0.82         0.89         0.74      0.47  0.88      0.76
# 6                0.82         0.89         0.74      0.47  0.89      0.76
# 7                0.83         0.89         0.76      0.49  0.89      0.78
# 8                0.83         0.89         0.76      0.49  0.89      0.78
# 9                0.82         0.89         0.75      0.48  0.89      0.77
# 10               0.79         0.91         0.67      0.42  0.89      0.70
# 11               0.79         0.91         0.67      0.42  0.89      0.70
# 12               0.84         0.87         0.80      0.53  0.89      0.81
# 13               0.84         0.87         0.80      0.53  0.89      0.81
# 14               0.81         0.91         0.71      0.45  0.89      0.74
# 15               0.83         0.89         0.76      0.49  0.88      0.77
# 16               0.81         0.89         0.72      0.45  0.89      0.74
# 17               0.80         0.94         0.66      0.42  0.89      0.69
# 18               0.80         0.94         0.66      0.42  0.89      0.69
# 19               0.82         0.89         0.74      0.47  0.89      0.76
# 20               0.83         0.89         0.78      0.50  0.89      0.79
# 21               0.83         0.89         0.76      0.49  0.89      0.78
# 22               0.83         0.89         0.76      0.49  0.89      0.78
# 23               0.79         0.94         0.63      0.40  0.89      0.67
# 24               0.80         0.91         0.69      0.43  0.89      0.72
# 25               0.82         0.85         0.79      0.50  0.89      0.80
# 26               0.82         0.85         0.79      0.50  0.89      0.80
# 27               0.83         0.87         0.79      0.51  0.89      0.80
# 28               0.83         0.87         0.79      0.51  0.89      0.80
# 29               0.82         0.91         0.73      0.47  0.89      0.75
# 30               0.82         0.91         0.73      0.47  0.89      0.75
# 31               0.83         0.85         0.81      0.52  0.89      0.81
# 32               0.83         0.85         0.81      0.52  0.89      0.81
# 33               0.82         0.91         0.73      0.47  0.89      0.75
# 34               0.83         0.91         0.74      0.48  0.88      0.76
# 35               0.83         0.91         0.74      0.48  0.88      0.76
# 36               0.83         0.89         0.77      0.50  0.89      0.79
# 37               0.81         0.91         0.71      0.45  0.89      0.73
# 38               0.81         0.91         0.71      0.45  0.89      0.73
# 39               0.83         0.85         0.80      0.52  0.88      0.81
# 40               0.83         0.85         0.80      0.52  0.88      0.81
# 41               0.83         0.91         0.75      0.48  0.88      0.77
# 42               0.81         0.91         0.71      0.45  0.88      0.73
# 43               0.83         0.91         0.74      0.48  0.88      0.76
# 44               0.83         0.91         0.74      0.48  0.88      0.76
# 45               0.82         0.91         0.72      0.46  0.89      0.74
# 46               0.82         0.91         0.72      0.46  0.89      0.74
# 47               0.83         0.89         0.76      0.49  0.88      0.77
#
#     precision  ... Estimator_Class  \
# 0        0.32  ...   MLPClassifier
# 1        0.32  ...   MLPClassifier
# 2        0.32  ...   MLPClassifier
# 3        0.32  ...   MLPClassifier
# 4        0.32  ...   MLPClassifier
# 5        0.32  ...   MLPClassifier
# 6        0.32  ...   MLPClassifier
# 7        0.34  ...   MLPClassifier
# 8        0.34  ...   MLPClassifier
# 9        0.33  ...   MLPClassifier
# 10       0.27  ...   MLPClassifier
# 11       0.27  ...   MLPClassifier
# 12       0.38  ...   MLPClassifier
# 13       0.38  ...   MLPClassifier
# 14       0.30  ...   MLPClassifier
# 15       0.33  ...   MLPClassifier
# 16       0.30  ...   MLPClassifier
# 17       0.27  ...   MLPClassifier
# 18       0.27  ...   MLPClassifier
# 19       0.32  ...   MLPClassifier
# 20       0.35  ...   MLPClassifier
# 21       0.34  ...   MLPClassifier
# 22       0.34  ...   MLPClassifier
# 23       0.26  ...   MLPClassifier
# 24       0.28  ...   MLPClassifier
# 25       0.35  ...   MLPClassifier
# 26       0.35  ...   MLPClassifier
# 27       0.36  ...   MLPClassifier
# 28       0.36  ...   MLPClassifier
# 29       0.31  ...   MLPClassifier
# 30       0.31  ...   MLPClassifier
# 31       0.38  ...   MLPClassifier
# 32       0.38  ...   MLPClassifier
# 33       0.31  ...   MLPClassifier
# 34       0.32  ...   MLPClassifier
# 35       0.32  ...   MLPClassifier
# 36       0.35  ...   MLPClassifier
# 37       0.30  ...   MLPClassifier
# 38       0.30  ...   MLPClassifier
# 39       0.37  ...   MLPClassifier
# 40       0.37  ...   MLPClassifier
# 41       0.33  ...   MLPClassifier
# 42       0.30  ...   MLPClassifier
# 43       0.32  ...   MLPClassifier
# 44       0.32  ...   MLPClassifier
# 45       0.31  ...   MLPClassifier
# 46       0.31  ...   MLPClassifier
# 47       0.33  ...   MLPClassifier
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                 Estimator_Hyperparams  \
# 0        {'activation':'relu','alpha':0.3,'batch_size':'auto','beta_1':0.9,'beta_2':0.999,'early_stopping':False,'epsilon':1e-08,'hidden_layer_sizes':22,'learning_rate':'constant','learning_rate_init':0.01,'max_fun':15000,'max_iter':2000,'momentum':0.9,'n_iter_no_change':10,'nesterovs_momentum':True,'power_t':0.5,'random_state':42,'shuffle':True,'solver':'sgd','tol':0.0001,'validation_fraction':0.1,'verbose':False,'warm_start':False}
# 1        {'activation':'relu','alpha':0.3,'batch_size':'auto','beta_1':0.9,'beta_2':0.999,'early_stopping':False,'epsilon':1e-08,'hidden_layer_sizes':22,'learning_rate':'constant','learning_rate_init':0.01,'max_fun':15000,'max_iter':2000,'momentum':0.9,'n_iter_no_change':10,'nesterovs_momentum':True,'power_t':0.5,'random_state':42,'shuffle':True,'solver':'sgd','tol':0.0001,'validation_fraction':0.1,'verbose':False,'warm_start':False}
# 2        {'activation':'relu','alpha':0.3,'batch_size':'auto','beta_1':0.9,'beta_2':0.999,'early_stopping':False,'epsilon':1e-08,'hidden_layer_sizes':22,'learning_rate':'constant','learning_rate_init':0.01,'max_fun':15000,'max_iter':2000,'momentum':0.9,'n_iter_no_change':10,'nesterovs_momentum':True,'power_t':0.5,'random_state':42,'shuffle':True,'solver':'sgd','tol':0.0001,'validation_fraction':0.1,'verbose':False,'warm_start':False}
# 3        {'activation':'relu','alpha':0.3,'batch_size':'auto','beta_1':0.9,'beta_2':0.999,'early_stopping':False,'epsilon':1e-08,'hidden_layer_sizes':22,'learning_rate':'constant','learning_rate_init':0.01,'max_fun':15000,'max_iter':2000,'momentum':0.9,'n_iter_no_change':10,'nesterovs_momentum':True,'power_t':0.5,'random_state':42,'shuffle':True,'solver':'sgd','tol':0.0001,'validation_fraction':0.1,'verbose':False,'warm_start':False}
# 4        {'activation':'relu','alpha':0.3,'batch_size':'auto','beta_1':0.9,'beta_2':0.999,'early_stopping':False,'epsilon':1e-08,'hidden_layer_sizes':22,'learning_rate':'constant','learning_rate_init':0.01,'max_fun':15000,'max_iter':2000,'momentum':0.9,'n_iter_no_change':10,'nesterovs_momentum':True,'power_t':0.5,'random_state':42,'shuffle':True,'solver':'sgd','tol':0.0001,'validation_fraction':0.1,'verbose':False,'warm_start':False}
# 5        {'activation':'relu','alpha':0.3,'batch_size':'auto','beta_1':0.9,'beta_2':0.999,'early_stopping':False,'epsilon':1e-08,'hidden_layer_sizes':22,'learning_rate':'constant','learning_rate_init':0.01,'max_fun':15000,'max_iter':2000,'momentum':0.9,'n_iter_no_change':10,'nesterovs_momentum':True,'power_t':0.5,'random_state':42,'shuffle':True,'solver':'sgd','tol':0.0001,'validation_fraction':0.1,'verbose':False,'warm_start':False}
# 6         {'activation':'relu','alpha':0.3,'batch_size':'auto','beta_1':0.9,'beta_2':0.999,'early_stopping':False,'epsilon':1e-08,'hidden_layer_sizes':22,'learning_rate':'constant','learning_rate_init':0.1,'max_fun':15000,'max_iter':2000,'momentum':0.9,'n_iter_no_change':10,'nesterovs_momentum':True,'power_t':0.5,'random_state':42,'shuffle':True,'solver':'sgd','tol':0.0001,'validation_fraction':0.1,'verbose':False,'warm_start':False}
# 7        {'activation':'relu','alpha':0.1,'batch_size':'auto','beta_1':0.9,'beta_2':0.999,'early_stopping':False,'epsilon':1e-08,'hidden_layer_sizes':22,'learning_rate':'constant','learning_rate_init':0.01,'max_fun':15000,'max_iter':2000,'momentum':0.9,'n_iter_no_change':10,'nesterovs_momentum':True,'power_t':0.5,'random_state':42,'shuffle':True,'solver':'sgd','tol':0.0001,'validation_fraction':0.1,'verbose':False,'warm_start':False}
# 8        {'activation':'relu','alpha':0.1,'batch_size':'auto','beta_1':0.9,'beta_2':0.999,'early_stopping':False,'epsilon':1e-08,'hidden_layer_sizes':22,'learning_rate':'constant','learning_rate_init':0.01,'max_fun':15000,'max_iter':2000,'momentum':0.9,'n_iter_no_change':10,'nesterovs_momentum':True,'power_t':0.5,'random_state':42,'shuffle':True,'solver':'sgd','tol':0.0001,'validation_fraction':0.1,'verbose':False,'warm_start':False}
# 9        {'activation':'relu','alpha':0.1,'batch_size':'auto','beta_1':0.9,'beta_2':0.999,'early_stopping':False,'epsilon':1e-08,'hidden_layer_sizes':22,'learning_rate':'constant','learning_rate_init':0.01,'max_fun':15000,'max_iter':2000,'momentum':0.9,'n_iter_no_change':10,'nesterovs_momentum':True,'power_t':0.5,'random_state':42,'shuffle':True,'solver':'sgd','tol':0.0001,'validation_fraction':0.1,'verbose':False,'warm_start':False}
# 10        {'activation':'relu','alpha':0.3,'batch_size':'auto','beta_1':0.9,'beta_2':0.999,'early_stopping':False,'epsilon':1e-08,'hidden_layer_sizes':22,'learning_rate':'constant','learning_rate_init':0.1,'max_fun':15000,'max_iter':2000,'momentum':0.9,'n_iter_no_change':10,'nesterovs_momentum':True,'power_t':0.5,'random_state':42,'shuffle':True,'solver':'sgd','tol':0.0001,'validation_fraction':0.1,'verbose':False,'warm_start':False}
# 11        {'activation':'relu','alpha':0.3,'batch_size':'auto','beta_1':0.9,'beta_2':0.999,'early_stopping':False,'epsilon':1e-08,'hidden_layer_sizes':22,'learning_rate':'constant','learning_rate_init':0.1,'max_fun':15000,'max_iter':2000,'momentum':0.9,'n_iter_no_change':10,'nesterovs_momentum':True,'power_t':0.5,'random_state':42,'shuffle':True,'solver':'sgd','tol':0.0001,'validation_fraction':0.1,'verbose':False,'warm_start':False}
# 12   {'activation':'relu','alpha':0.3,'batch_size':'auto','beta_1':0.9,'beta_2':0.999,'early_stopping':False,'epsilon':1e-08,'hidden_layer_sizes':(30,30),'learning_rate':'constant','learning_rate_init':0.1,'max_fun':15000,'max_iter':2000,'momentum':0.9,'n_iter_no_change':10,'nesterovs_momentum':True,'power_t':0.5,'random_state':42,'shuffle':True,'solver':'sgd','tol':0.0001,'validation_fraction':0.1,'verbose':False,'warm_start':False}
# 13   {'activation':'relu','alpha':0.3,'batch_size':'auto','beta_1':0.9,'beta_2':0.999,'early_stopping':False,'epsilon':1e-08,'hidden_layer_sizes':(30,30),'learning_rate':'constant','learning_rate_init':0.1,'max_fun':15000,'max_iter':2000,'momentum':0.9,'n_iter_no_change':10,'nesterovs_momentum':True,'power_t':0.5,'random_state':42,'shuffle':True,'solver':'sgd','tol':0.0001,'validation_fraction':0.1,'verbose':False,'warm_start':False}
# 14   {'activation':'relu','alpha':0.3,'batch_size':'auto','beta_1':0.9,'beta_2':0.999,'early_stopping':False,'epsilon':1e-08,'hidden_layer_sizes':(30,30),'learning_rate':'constant','learning_rate_init':0.1,'max_fun':15000,'max_iter':2000,'momentum':0.9,'n_iter_no_change':10,'nesterovs_momentum':True,'power_t':0.5,'random_state':42,'shuffle':True,'solver':'sgd','tol':0.0001,'validation_fraction':0.1,'verbose':False,'warm_start':False}
# 15       {'activation':'relu','alpha':0.1,'batch_size':'auto','beta_1':0.9,'beta_2':0.999,'early_stopping':False,'epsilon':1e-08,'hidden_layer_sizes':22,'learning_rate':'constant','learning_rate_init':0.01,'max_fun':15000,'max_iter':2000,'momentum':0.9,'n_iter_no_change':10,'nesterovs_momentum':True,'power_t':0.5,'random_state':42,'shuffle':True,'solver':'sgd','tol':0.0001,'validation_fraction':0.1,'verbose':False,'warm_start':False}
# 16        {'activation':'relu','alpha':0.3,'batch_size':'auto','beta_1':0.9,'beta_2':0.999,'early_stopping':False,'epsilon':1e-08,'hidden_layer_sizes':22,'learning_rate':'constant','learning_rate_init':0.1,'max_fun':15000,'max_iter':2000,'momentum':0.9,'n_iter_no_change':10,'nesterovs_momentum':True,'power_t':0.5,'random_state':42,'shuffle':True,'solver':'sgd','tol':0.0001,'validation_fraction':0.1,'verbose':False,'warm_start':False}
# 17        {'activation':'relu','alpha':0.3,'batch_size':'auto','beta_1':0.9,'beta_2':0.999,'early_stopping':False,'epsilon':1e-08,'hidden_layer_sizes':22,'learning_rate':'constant','learning_rate_init':0.1,'max_fun':15000,'max_iter':2000,'momentum':0.9,'n_iter_no_change':10,'nesterovs_momentum':True,'power_t':0.5,'random_state':42,'shuffle':True,'solver':'sgd','tol':0.0001,'validation_fraction':0.1,'verbose':False,'warm_start':False}
# 18        {'activation':'relu','alpha':0.3,'batch_size':'auto','beta_1':0.9,'beta_2':0.999,'early_stopping':False,'epsilon':1e-08,'hidden_layer_sizes':22,'learning_rate':'constant','learning_rate_init':0.1,'max_fun':15000,'max_iter':2000,'momentum':0.9,'n_iter_no_change':10,'nesterovs_momentum':True,'power_t':0.5,'random_state':42,'shuffle':True,'solver':'sgd','tol':0.0001,'validation_fraction':0.1,'verbose':False,'warm_start':False}
# 19        {'activation':'relu','alpha':0.1,'batch_size':'auto','beta_1':0.9,'beta_2':0.999,'early_stopping':False,'epsilon':1e-08,'hidden_layer_sizes':22,'learning_rate':'constant','learning_rate_init':0.1,'max_fun':15000,'max_iter':2000,'momentum':0.9,'n_iter_no_change':10,'nesterovs_momentum':True,'power_t':0.5,'random_state':42,'shuffle':True,'solver':'sgd','tol':0.0001,'validation_fraction':0.1,'verbose':False,'warm_start':False}
# 20   {'activation':'relu','alpha':0.1,'batch_size':'auto','beta_1':0.9,'beta_2':0.999,'early_stopping':False,'epsilon':1e-08,'hidden_layer_sizes':(30,30),'learning_rate':'constant','learning_rate_init':0.1,'max_fun':15000,'max_iter':2000,'momentum':0.9,'n_iter_no_change':10,'nesterovs_momentum':True,'power_t':0.5,'random_state':42,'shuffle':True,'solver':'sgd','tol':0.0001,'validation_fraction':0.1,'verbose':False,'warm_start':False}
# 21       {'activation':'relu','alpha':0.1,'batch_size':'auto','beta_1':0.9,'beta_2':0.999,'early_stopping':False,'epsilon':1e-08,'hidden_layer_sizes':22,'learning_rate':'constant','learning_rate_init':0.01,'max_fun':15000,'max_iter':2000,'momentum':0.9,'n_iter_no_change':10,'nesterovs_momentum':True,'power_t':0.5,'random_state':42,'shuffle':True,'solver':'sgd','tol':0.0001,'validation_fraction':0.1,'verbose':False,'warm_start':False}
# 22       {'activation':'relu','alpha':0.1,'batch_size':'auto','beta_1':0.9,'beta_2':0.999,'early_stopping':False,'epsilon':1e-08,'hidden_layer_sizes':22,'learning_rate':'constant','learning_rate_init':0.01,'max_fun':15000,'max_iter':2000,'momentum':0.9,'n_iter_no_change':10,'nesterovs_momentum':True,'power_t':0.5,'random_state':42,'shuffle':True,'solver':'sgd','tol':0.0001,'validation_fraction':0.1,'verbose':False,'warm_start':False}
# 23   {'activation':'relu','alpha':0.3,'batch_size':'auto','beta_1':0.9,'beta_2':0.999,'early_stopping':False,'epsilon':1e-08,'hidden_layer_sizes':(30,30),'learning_rate':'constant','learning_rate_init':0.1,'max_fun':15000,'max_iter':2000,'momentum':0.9,'n_iter_no_change':10,'nesterovs_momentum':True,'power_t':0.5,'random_state':42,'shuffle':True,'solver':'sgd','tol':0.0001,'validation_fraction':0.1,'verbose':False,'warm_start':False}
# 24   {'activation':'relu','alpha':0.1,'batch_size':'auto','beta_1':0.9,'beta_2':0.999,'early_stopping':False,'epsilon':1e-08,'hidden_layer_sizes':(30,30),'learning_rate':'constant','learning_rate_init':0.1,'max_fun':15000,'max_iter':2000,'momentum':0.9,'n_iter_no_change':10,'nesterovs_momentum':True,'power_t':0.5,'random_state':42,'shuffle':True,'solver':'sgd','tol':0.0001,'validation_fraction':0.1,'verbose':False,'warm_start':False}
# 25   {'activation':'relu','alpha':0.1,'batch_size':'auto','beta_1':0.9,'beta_2':0.999,'early_stopping':False,'epsilon':1e-08,'hidden_layer_sizes':(30,30),'learning_rate':'constant','learning_rate_init':0.1,'max_fun':15000,'max_iter':2000,'momentum':0.9,'n_iter_no_change':10,'nesterovs_momentum':True,'power_t':0.5,'random_state':42,'shuffle':True,'solver':'sgd','tol':0.0001,'validation_fraction':0.1,'verbose':False,'warm_start':False}
# 26   {'activation':'relu','alpha':0.1,'batch_size':'auto','beta_1':0.9,'beta_2':0.999,'early_stopping':False,'epsilon':1e-08,'hidden_layer_sizes':(30,30),'learning_rate':'constant','learning_rate_init':0.1,'max_fun':15000,'max_iter':2000,'momentum':0.9,'n_iter_no_change':10,'nesterovs_momentum':True,'power_t':0.5,'random_state':42,'shuffle':True,'solver':'sgd','tol':0.0001,'validation_fraction':0.1,'verbose':False,'warm_start':False}
# 27   {'activation':'relu','alpha':0.3,'batch_size':'auto','beta_1':0.9,'beta_2':0.999,'early_stopping':False,'epsilon':1e-08,'hidden_layer_sizes':(30,30),'learning_rate':'constant','learning_rate_init':0.1,'max_fun':15000,'max_iter':2000,'momentum':0.9,'n_iter_no_change':10,'nesterovs_momentum':True,'power_t':0.5,'random_state':42,'shuffle':True,'solver':'sgd','tol':0.0001,'validation_fraction':0.1,'verbose':False,'warm_start':False}
# 28   {'activation':'relu','alpha':0.3,'batch_size':'auto','beta_1':0.9,'beta_2':0.999,'early_stopping':False,'epsilon':1e-08,'hidden_layer_sizes':(30,30),'learning_rate':'constant','learning_rate_init':0.1,'max_fun':15000,'max_iter':2000,'momentum':0.9,'n_iter_no_change':10,'nesterovs_momentum':True,'power_t':0.5,'random_state':42,'shuffle':True,'solver':'sgd','tol':0.0001,'validation_fraction':0.1,'verbose':False,'warm_start':False}
# 29  {'activation':'relu','alpha':0.3,'batch_size':'auto','beta_1':0.9,'beta_2':0.999,'early_stopping':False,'epsilon':1e-08,'hidden_layer_sizes':(30,30),'learning_rate':'constant','learning_rate_init':0.01,'max_fun':15000,'max_iter':2000,'momentum':0.9,'n_iter_no_change':10,'nesterovs_momentum':True,'power_t':0.5,'random_state':42,'shuffle':True,'solver':'sgd','tol':0.0001,'validation_fraction':0.1,'verbose':False,'warm_start':False}
# 30  {'activation':'relu','alpha':0.3,'batch_size':'auto','beta_1':0.9,'beta_2':0.999,'early_stopping':False,'epsilon':1e-08,'hidden_layer_sizes':(30,30),'learning_rate':'constant','learning_rate_init':0.01,'max_fun':15000,'max_iter':2000,'momentum':0.9,'n_iter_no_change':10,'nesterovs_momentum':True,'power_t':0.5,'random_state':42,'shuffle':True,'solver':'sgd','tol':0.0001,'validation_fraction':0.1,'verbose':False,'warm_start':False}
# 31        {'activation':'relu','alpha':0.1,'batch_size':'auto','beta_1':0.9,'beta_2':0.999,'early_stopping':False,'epsilon':1e-08,'hidden_layer_sizes':22,'learning_rate':'constant','learning_rate_init':0.1,'max_fun':15000,'max_iter':2000,'momentum':0.9,'n_iter_no_change':10,'nesterovs_momentum':True,'power_t':0.5,'random_state':42,'shuffle':True,'solver':'sgd','tol':0.0001,'validation_fraction':0.1,'verbose':False,'warm_start':False}
# 32        {'activation':'relu','alpha':0.1,'batch_size':'auto','beta_1':0.9,'beta_2':0.999,'early_stopping':False,'epsilon':1e-08,'hidden_layer_sizes':22,'learning_rate':'constant','learning_rate_init':0.1,'max_fun':15000,'max_iter':2000,'momentum':0.9,'n_iter_no_change':10,'nesterovs_momentum':True,'power_t':0.5,'random_state':42,'shuffle':True,'solver':'sgd','tol':0.0001,'validation_fraction':0.1,'verbose':False,'warm_start':False}
# 33  {'activation':'relu','alpha':0.3,'batch_size':'auto','beta_1':0.9,'beta_2':0.999,'early_stopping':False,'epsilon':1e-08,'hidden_layer_sizes':(30,30),'learning_rate':'constant','learning_rate_init':0.01,'max_fun':15000,'max_iter':2000,'momentum':0.9,'n_iter_no_change':10,'nesterovs_momentum':True,'power_t':0.5,'random_state':42,'shuffle':True,'solver':'sgd','tol':0.0001,'validation_fraction':0.1,'verbose':False,'warm_start':False}
# 34  {'activation':'relu','alpha':0.1,'batch_size':'auto','beta_1':0.9,'beta_2':0.999,'early_stopping':False,'epsilon':1e-08,'hidden_layer_sizes':(30,30),'learning_rate':'constant','learning_rate_init':0.01,'max_fun':15000,'max_iter':2000,'momentum':0.9,'n_iter_no_change':10,'nesterovs_momentum':True,'power_t':0.5,'random_state':42,'shuffle':True,'solver':'sgd','tol':0.0001,'validation_fraction':0.1,'verbose':False,'warm_start':False}
# 35  {'activation':'relu','alpha':0.1,'batch_size':'auto','beta_1':0.9,'beta_2':0.999,'early_stopping':False,'epsilon':1e-08,'hidden_layer_sizes':(30,30),'learning_rate':'constant','learning_rate_init':0.01,'max_fun':15000,'max_iter':2000,'momentum':0.9,'n_iter_no_change':10,'nesterovs_momentum':True,'power_t':0.5,'random_state':42,'shuffle':True,'solver':'sgd','tol':0.0001,'validation_fraction':0.1,'verbose':False,'warm_start':False}
# 36        {'activation':'relu','alpha':0.1,'batch_size':'auto','beta_1':0.9,'beta_2':0.999,'early_stopping':False,'epsilon':1e-08,'hidden_layer_sizes':22,'learning_rate':'constant','learning_rate_init':0.1,'max_fun':15000,'max_iter':2000,'momentum':0.9,'n_iter_no_change':10,'nesterovs_momentum':True,'power_t':0.5,'random_state':42,'shuffle':True,'solver':'sgd','tol':0.0001,'validation_fraction':0.1,'verbose':False,'warm_start':False}
# 37   {'activation':'relu','alpha':0.1,'batch_size':'auto','beta_1':0.9,'beta_2':0.999,'early_stopping':False,'epsilon':1e-08,'hidden_layer_sizes':(30,30),'learning_rate':'constant','learning_rate_init':0.1,'max_fun':15000,'max_iter':2000,'momentum':0.9,'n_iter_no_change':10,'nesterovs_momentum':True,'power_t':0.5,'random_state':42,'shuffle':True,'solver':'sgd','tol':0.0001,'validation_fraction':0.1,'verbose':False,'warm_start':False}
# 38   {'activation':'relu','alpha':0.1,'batch_size':'auto','beta_1':0.9,'beta_2':0.999,'early_stopping':False,'epsilon':1e-08,'hidden_layer_sizes':(30,30),'learning_rate':'constant','learning_rate_init':0.1,'max_fun':15000,'max_iter':2000,'momentum':0.9,'n_iter_no_change':10,'nesterovs_momentum':True,'power_t':0.5,'random_state':42,'shuffle':True,'solver':'sgd','tol':0.0001,'validation_fraction':0.1,'verbose':False,'warm_start':False}
# 39        {'activation':'relu','alpha':0.1,'batch_size':'auto','beta_1':0.9,'beta_2':0.999,'early_stopping':False,'epsilon':1e-08,'hidden_layer_sizes':22,'learning_rate':'constant','learning_rate_init':0.1,'max_fun':15000,'max_iter':2000,'momentum':0.9,'n_iter_no_change':10,'nesterovs_momentum':True,'power_t':0.5,'random_state':42,'shuffle':True,'solver':'sgd','tol':0.0001,'validation_fraction':0.1,'verbose':False,'warm_start':False}
# 40        {'activation':'relu','alpha':0.1,'batch_size':'auto','beta_1':0.9,'beta_2':0.999,'early_stopping':False,'epsilon':1e-08,'hidden_layer_sizes':22,'learning_rate':'constant','learning_rate_init':0.1,'max_fun':15000,'max_iter':2000,'momentum':0.9,'n_iter_no_change':10,'nesterovs_momentum':True,'power_t':0.5,'random_state':42,'shuffle':True,'solver':'sgd','tol':0.0001,'validation_fraction':0.1,'verbose':False,'warm_start':False}
# 41  {'activation':'relu','alpha':0.1,'batch_size':'auto','beta_1':0.9,'beta_2':0.999,'early_stopping':False,'epsilon':1e-08,'hidden_layer_sizes':(30,30),'learning_rate':'constant','learning_rate_init':0.01,'max_fun':15000,'max_iter':2000,'momentum':0.9,'n_iter_no_change':10,'nesterovs_momentum':True,'power_t':0.5,'random_state':42,'shuffle':True,'solver':'sgd','tol':0.0001,'validation_fraction':0.1,'verbose':False,'warm_start':False}
# 42  {'activation':'relu','alpha':0.3,'batch_size':'auto','beta_1':0.9,'beta_2':0.999,'early_stopping':False,'epsilon':1e-08,'hidden_layer_sizes':(30,30),'learning_rate':'constant','learning_rate_init':0.01,'max_fun':15000,'max_iter':2000,'momentum':0.9,'n_iter_no_change':10,'nesterovs_momentum':True,'power_t':0.5,'random_state':42,'shuffle':True,'solver':'sgd','tol':0.0001,'validation_fraction':0.1,'verbose':False,'warm_start':False}
# 43  {'activation':'relu','alpha':0.1,'batch_size':'auto','beta_1':0.9,'beta_2':0.999,'early_stopping':False,'epsilon':1e-08,'hidden_layer_sizes':(30,30),'learning_rate':'constant','learning_rate_init':0.01,'max_fun':15000,'max_iter':2000,'momentum':0.9,'n_iter_no_change':10,'nesterovs_momentum':True,'power_t':0.5,'random_state':42,'shuffle':True,'solver':'sgd','tol':0.0001,'validation_fraction':0.1,'verbose':False,'warm_start':False}
# 44  {'activation':'relu','alpha':0.1,'batch_size':'auto','beta_1':0.9,'beta_2':0.999,'early_stopping':False,'epsilon':1e-08,'hidden_layer_sizes':(30,30),'learning_rate':'constant','learning_rate_init':0.01,'max_fun':15000,'max_iter':2000,'momentum':0.9,'n_iter_no_change':10,'nesterovs_momentum':True,'power_t':0.5,'random_state':42,'shuffle':True,'solver':'sgd','tol':0.0001,'validation_fraction':0.1,'verbose':False,'warm_start':False}
# 45  {'activation':'relu','alpha':0.3,'batch_size':'auto','beta_1':0.9,'beta_2':0.999,'early_stopping':False,'epsilon':1e-08,'hidden_layer_sizes':(30,30),'learning_rate':'constant','learning_rate_init':0.01,'max_fun':15000,'max_iter':2000,'momentum':0.9,'n_iter_no_change':10,'nesterovs_momentum':True,'power_t':0.5,'random_state':42,'shuffle':True,'solver':'sgd','tol':0.0001,'validation_fraction':0.1,'verbose':False,'warm_start':False}
# 46  {'activation':'relu','alpha':0.3,'batch_size':'auto','beta_1':0.9,'beta_2':0.999,'early_stopping':False,'epsilon':1e-08,'hidden_layer_sizes':(30,30),'learning_rate':'constant','learning_rate_init':0.01,'max_fun':15000,'max_iter':2000,'momentum':0.9,'n_iter_no_change':10,'nesterovs_momentum':True,'power_t':0.5,'random_state':42,'shuffle':True,'solver':'sgd','tol':0.0001,'validation_fraction':0.1,'verbose':False,'warm_start':False}
# 47  {'activation':'relu','alpha':0.1,'batch_size':'auto','beta_1':0.9,'beta_2':0.999,'early_stopping':False,'epsilon':1e-08,'hidden_layer_sizes':(30,30),'learning_rate':'constant','learning_rate_init':0.01,'max_fun':15000,'max_iter':2000,'momentum':0.9,'n_iter_no_change':10,'nesterovs_momentum':True,'power_t':0.5,'random_state':42,'shuffle':True,'solver':'sgd','tol':0.0001,'validation_fraction':0.1,'verbose':False,'warm_start':False}
#
#    fit_time train_balanced_accuracy train_sensitivity  train_specificity  \
# 0      0.01                    0.79              0.79               0.78
# 1      0.01                    0.79              0.79               0.78
# 2      0.01                    0.78              0.78               0.78
# 3      0.01                    0.78              0.78               0.78
# 4      0.01                    0.78              0.78               0.78
# 5      0.01                    0.78              0.78               0.78
# 6      0.01                    0.77              0.77               0.77
# 7      0.01                    0.77              0.77               0.77
# 8      0.01                    0.77              0.77               0.77
# 9      0.01                    0.77              0.77               0.77
# 10     0.01                    0.77              0.76               0.78
# 11     0.01                    0.77              0.76               0.78
# 12     0.01                    0.77              0.76               0.78
# 13     0.01                    0.77              0.76               0.78
# 14     0.01                    0.77              0.76               0.78
# 15     0.01                    0.76              0.77               0.76
# 16     0.01                    0.76              0.77               0.76
# 17     0.01                    0.76              0.75               0.78
# 18     0.01                    0.76              0.75               0.78
# 19     0.01                    0.76              0.76               0.77
# 20     0.01                    0.76              0.76               0.77
# 21     0.01                    0.76              0.76               0.77
# 22     0.01                    0.76              0.76               0.77
# 23     0.01                    0.76              0.76               0.76
# 24     0.01                    0.76              0.75               0.77
# 25     0.01                    0.76              0.75               0.77
# 26     0.01                    0.76              0.75               0.77
# 27     0.01                    0.76              0.74               0.77
# 28     0.01                    0.76              0.74               0.77
# 29     0.01                    0.76              0.75               0.76
# 30     0.01                    0.76              0.75               0.76
# 31     0.01                    0.76              0.75               0.76
# 32     0.01                    0.76              0.75               0.76
# 33     0.01                    0.75              0.74               0.77
# 34     0.01                    0.75              0.74               0.76
# 35     0.01                    0.75              0.74               0.76
# 36     0.01                    0.75              0.75               0.75
# 37     0.01                    0.75              0.74               0.76
# 38     0.01                    0.75              0.74               0.76
# 39     0.01                    0.75              0.75               0.75
# 40     0.01                    0.75              0.75               0.75
# 41     0.01                    0.75              0.74               0.76
# 42     0.01                    0.75              0.73               0.76
# 43     0.01                    0.75              0.73               0.76
# 44     0.01                    0.75              0.73               0.76
# 45     0.01                    0.75              0.73               0.76
# 46     0.01                    0.75              0.73               0.76
# 47     0.01                    0.74              0.73               0.75
#
#     train_f1_score  train_AUC  train_accuracy  train_precision
# 0             0.48       0.85            0.78             0.35
# 1             0.48       0.85            0.78             0.35
# 2             0.48       0.85            0.78             0.35
# 3             0.48       0.85            0.78             0.35
# 4             0.47       0.85            0.78             0.34
# 5             0.47       0.85            0.78             0.34
# 6             0.47       0.84            0.77             0.34
# 7             0.47       0.84            0.77             0.34
# 8             0.47       0.84            0.77             0.34
# 9             0.47       0.84            0.77             0.34
# 10            0.47       0.84            0.77             0.34
# 11            0.47       0.84            0.77             0.34
# 12            0.47       0.84            0.77             0.34
# 13            0.47       0.84            0.77             0.34
# 14            0.47       0.83            0.77             0.34
# 15            0.46       0.83            0.76             0.33
# 16            0.46       0.83            0.76             0.33
# 17            0.46       0.83            0.77             0.34
# 18            0.46       0.83            0.77             0.34
# 19            0.46       0.83            0.77             0.33
# 20            0.46       0.84            0.77             0.33
# 21            0.46       0.83            0.77             0.33
# 22            0.46       0.83            0.77             0.33
# 23            0.45       0.83            0.76             0.33
# 24            0.45       0.83            0.76             0.32
# 25            0.45       0.83            0.76             0.33
# 26            0.45       0.83            0.76             0.33
# 27            0.45       0.82            0.77             0.33
# 28            0.45       0.82            0.77             0.33
# 29            0.45       0.82            0.76             0.32
# 30            0.45       0.82            0.76             0.32
# 31            0.45       0.83            0.76             0.32
# 32            0.45       0.83            0.76             0.32
# 33            0.45       0.82            0.76             0.32
# 34            0.45       0.82            0.76             0.32
# 35            0.45       0.82            0.76             0.32
# 36            0.44       0.82            0.75             0.31
# 37            0.45       0.82            0.76             0.32
# 38            0.45       0.82            0.76             0.32
# 39            0.44       0.82            0.75             0.31
# 40            0.44       0.82            0.75             0.31
# 41            0.44       0.82            0.76             0.32
# 42            0.44       0.81            0.76             0.31
# 43            0.44       0.80            0.76             0.31
# 44            0.44       0.80            0.76             0.31
# 45            0.44       0.81            0.75             0.31
# 46            0.44       0.81            0.75             0.31
# 47            0.43       0.80            0.75             0.31
#
# [48 rows x 23 columns]

# %%
file = open(
    'exec_results/serialized_data/grid_search__TESTING__DT__All_Features__Ensemble_Imbalance__BalBagging.pickle', 
    'rb',
)

# dump information to that file
obj = pickle.load(file)

obj.cv_results_
